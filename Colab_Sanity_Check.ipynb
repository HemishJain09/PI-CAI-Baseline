# %% [markdown]
# # PI-CAI nnUNet Pipeline - Colab Sanity Check
# This notebook verifies the end-to-end execution of the Z-SSMNet pipeline.

# %%
from google.colab import drive
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Set Workspace path
# IMPORTANT: Change 'Colab_Test' to the folder name where you copied the 'baseline' folder in your Drive.
WORKSPACE_DIR = "/content/drive/MyDrive/Colab_Test/baseline"
os.environ["WORKSPACE_DIR"] = WORKSPACE_DIR

# %%
# %%bash
# cd $WORKSPACE_DIR
# # Patch hardcoded macOS paths to use Colab paths dynamically
# sed -i "s|/Users/hemishjain/Desktop/PI-CAI/baseline|$WORKSPACE_DIR|g" run_nnunet_pipeline.sh
# sed -i "s|/Users/hemishjain/Desktop/PI-CAI/baseline|$WORKSPACE_DIR|g" nnunet_prepare.py
# sed -i "s|/Users/hemishjain/Desktop/PI-CAI/baseline|$WORKSPACE_DIR|g" nnunet_zonal_integration.py
#
# # Fix Z-SSMNet reference path (assumes Z-SSMNet folder is uploaded next to baseline)
# sed -i "s|/Users/hemishjain/Desktop/PI-CAI/Z-SSMNet|$WORKSPACE_DIR/../Z-SSMNet|g" run_nnunet_pipeline.sh

# %%
# %%bash
# cd $WORKSPACE_DIR
# echo "Installing dependencies..."
# pip install -r requirements.txt
#
# echo "Installing DIAGNijmegen custom nnUNet fork..."
# export SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True
# pip install git+https://github.com/DIAGNijmegen/nnUNet.git@1.7.0-3

# %%
# %%bash
# cd $WORKSPACE_DIR
#
# # Ensure Sklearn deprecation warnings don't block execution
# export SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True
#
# # Make orchestrator executable and run
# chmod +x run_nnunet_pipeline.sh
# ./run_nnunet_pipeline.sh
